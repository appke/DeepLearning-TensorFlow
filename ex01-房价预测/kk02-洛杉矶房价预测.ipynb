# %% [markdown]
# # 洛杉矶房价预测
# 结构化数据的 回归问题
#
# 神经网络做结构化数据，效果不如xgboost

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('datas/los_data.csv') # 训练集的读取

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info() # 类型统计

# %%
train.info()
# 统计数据缺失率

# %%
train.isnull().head()
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  False       False     False        False    False   False   True     False
# 1  False       False     False        False    False   False   True     False
# 2  False       False     False        False    False   False   True     False
# 3  False       False     False        False    False   False   True     False
# 4  False       False     False        False    False   False   True     False
#
#    LandContour  Utilities    ...      PoolArea  PoolQC  Fence  MiscFeature  \
# 0        False      False    ...         False    True   True         True
# 1        False      False    ...         False    True   True         True
# 2        False      False    ...         False    True   True         True
# 3        False      False    ...         False    True   True         True
# 4        False      False    ...         False    True   True         True
#
# ...

# %% [markdown]
# 1. 那些列有缺失？
# 2. 缺失了多少？
# 3. 缺失率是多少
# 4. 可否安缺失率由大到小排序

# %%
nullRate=train.isnull().sum()

# %%
tmp=train.isnull().sum()
tmp[tmp>0].shape
# Out:
# (19,)

# %%
nullRate[i/len(train) for i in nullRate]
# Out:
#   File "<ipython-input-15-da85ef2c921e>", line 1
#     nullRate[i/len(train) for i in nullRate]
#                             ^
# SyntaxError: invalid syntax

# %%
tmp=nullRate.isnull().sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5aaa61f0658d> in <module>()
# ----> 1 tmp=nullRate.isnull().sum().sort_values()
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_values'

# %% [markdown]
# ## 数据的简单填充
# ### 缺失值得类型
# - Numerical | Categorial
#
#
# #### Numerical
# 1. 均值填充
# 2. 中位数填充
# 3. 高频填充-- 会“稍微”少一些 -- 连续型数据很难数字相等，但是很容易接近
# 4. 分布拟合填充 -- 回归一个分布，或者是（$\mu$-均值，$\sigma$-标准差）-（+-$\sigma$的范围中进行）
# 5. 内在关系填充（根据列本身存在的意义和数据集内，其它列的相关性，进行构建数学映射模型进行填充）
#
# #### Categorial
# 1. 高频填充
#
# "男"|"女" --> 0|1
#
# "小孩"|"青年"|"中年"|"老年" --> 0|1|2|3
#
# 2. 内在关系填充

# %% [markdown]
# Palantir -- 一战成名 -- 找到拉登老巢
#
# 人脸，知道你的心跳❤️

# %%
train.mean()

# %%
train.isnull().sum()

# %%
train2=train.fillna(train.mean()) # fillna函数会找到对列的均值 或 中位数，对于该列进行相应的填充

# %%
tmp=train2.isnull().sum()
tmp[tmp>0].shape
# Out:
# (16,)

# %% [markdown]
# #### 对于离散型数据进行填充
#
# 朴素办法：将NaN这种空类型变成“None”或者是“NA”的字段

# %%
train2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train3=train2.fillna("None")

# %%
train3.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0   None  None        None       0
# 1         Lvl    AllPub    ...            0   None  None        None       0
# 2         Lvl    AllPub    ...            0   None  None        None       0
# 3         Lvl    AllPub    ...            0   None  None        None       0
# 4         Lvl    AllPub    ...            0   None  None        None       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def getNullCount(t):
    tmp=t.isnull().sum()
    print(tmp[tmp>0])

# %%
getNullCount(train3) # 填充完毕
# Out:
# Series([], dtype: int64)

# %% [markdown]
# 到目前为止，完成了“暴力”填充阶段
# 目前的训练集噪声很大，留给后面EDA（Exploria Data Analysis）过程
#
# 探索性数据分析，发现新的Feature
# 对业务的落地很重要
#
# 数据科学家的缺失，数据专家！跟年限有关
#
# 先提交再优化改进！

# %% [markdown]
# ## 制作训练集
# 1.y标签
#
# 2.数据里面有Id？pandas伪造出来的
#
# 3.答案分出来了，还把答案放进去？？

# %%
y=train3['SalePrice']# 标签label
train4=train3.drop(['Id', 'SalePrice'],axis=1)

# %%
train4.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0   None
# 1         Lvl    AllPub       FR2      ...                 0        0   None
# 2         Lvl    AllPub    Inside      ...                 0        0   None
# 3         Lvl    AllPub    Corner      ...                 0        0   None
# 4         Lvl    AllPub       FR2      ...                 0        0   None
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
X=pd.get_dummies(train4) # 结构化数据

# %%
X.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0          2003       196.0         706           0          ...
# 1          1976         0.0         978           0          ...
# 2          2002       162.0         486           0          ...
# 3          1970         0.0         216           0          ...
# 4          2000       350.0         655           0          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
X.shape
# Out:
# (1460, 303)

# %% [markdown]
# ## 数据切分
# 分一些数据做评测

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2,random_state=123)

# %%
X_train.shape
# Out:
# (1168, 303)

# %%
X_test.shape
# Out:
# (292, 303)

# %% [markdown]
# ## 模型预测

# %%
import xgboost as xgb

# %%
# xgb.reg_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-db009c01c2d3> in <module>()
# ----> 1 xgb.reg_
#
# AttributeError: module 'xgboost' has no attribute 'reg_'

# %% [markdown]
# ## 进行模型评测

# %%
pred=xgb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1acafa1163f5> in <module>()
# ----> 1 pred=xgb.predict(X_test)
#
# AttributeError: module 'xgboost' has no attribute 'predict'

# %%
rmse=np.sqrt(mean_squared_error(y_test,pred))
rmse

# %%
logrmse=np.sqrt(mean_squared_error(np.log(y_test),np.log(pred)))

# %% [markdown]
# 使用中位数填充，调整超级参数，看看是否可以得到一个更好的模型

# %% [markdown]
# GDBT
# ## Randomized Search

# %% [markdown]
# ## 交叉验证

# %%
params = {"objective":"reg:liner", "colsample_bytree":0.7, 'learning_rate':0.1, 
         'max_depth': 10, 'alpha':10}

# %%
matrix-xgb.DMatrix(data=X,label=y)

# %%
X.shape

# %%
cv_result = xgb.cv(params, nfold=10,num_boost_round=500,metris='rmse',as_pandas=True)

# %%
train4.get_dtype_counts()  # 各自有什么属性 one hot编码
# Out:
# float64     3
# int64      33
# object     43
# dtype: int64

# %%
X=pd.get_dummies(train1) # Convert categorical variable into dummy/indicator variables
# 进行
